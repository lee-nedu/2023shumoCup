# %%
import random

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from algorithm import ewm

plt.rcParams['font.sans-serif'] = ['SimHei']  # 黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决无法显示符号的问题
palette = 'deep'
sns.set(font='SimHei', font_scale=1.2, palette=palette)  # 解决Seaborn中文显示问题

# %%
df = pd.DataFrame([
    [0.197, 0.605, ],
    [0.495, 0.478, ],
    [0.73, 0.425, ],
    [0.57, 0.479, ],
    [0.572, 0.437, ],
    [-0.205, 0.779, ],
], columns=['删除的项与删除项后的总体的相关性', '删除后的Cronbach\'s α系数'], index=[
    '对AI的需求程度(Q1)',
    '对网络认识的深度(Q2)',
    '倾向于使用软件进行的程度(Q3)',
    '对学习的热爱程度(Q4)',
    '对AI的认可程度(Q5)',
    '对AI工具否定程度(Q6)',
])
df
# Out:
#                   删除的项与删除项后的总体的相关性  删除后的Cronbach's α系数
# 对AI的需求程度(Q1)                 0.197               0.605
# 对网络认识的深度(Q2)                 0.495               0.478
# 倾向于使用软件进行的程度(Q3)             0.730               0.425
# 对学习的热爱程度(Q4)                 0.570               0.479
# 对AI的认可程度(Q5)                 0.572               0.437
# 对AI工具否定程度(Q6)               -0.205               0.779

# %%
sns.heatmap(df, cmap='Blues', annot=True, fmt='0.2f')
plt.xticks(rotation=10)
plt.tight_layout()
plt.savefig('表5-6 删除测试分析汇总表.svg')
plt.show()

# %%
df5_10 = pd.read_excel('表5-10 一级指标部分问卷得分情况.xlsx')
df5_10
# Out:
#    问卷序号  对AI的需求程度(Q1)得分  对网络认识的深度(Q2)得分  倾向于使用软件进行的程度(Q3)得分  对学习的热爱程度(Q4)得分
# 0     1        0.017864        0.013536            0.012230        0.015204  \
# 1     2        0.008990        0.008978            0.017193        0.018131
# 2     3        0.019690        0.016314            0.019203        0.017949
# 3     4        0.011807        0.021088            0.021069        0.022082
# 4     5        0.018552        0.014187            0.012711        0.011333
# 5     6        0.017368        0.016364            0.012266        0.016281
# 6     7        0.019690        0.011169            0.014578        0.013364
# 7     8        0.020141        0.011184            0.012462        0.016119
# 8     9        0.006714        0.005932            0.007877        0.008788
# 9    10        0.007164        0.011972            0.008535        0.009041
#
#    对AI的认可程度(Q5)得分
# 0        0.008306
# 1        0.020671
# 2        0.019630
# 3        0.022921
# 4        0.011620
# ...

# %%
plt.figure(figsize=(6, 6))
heatmap = sns.heatmap(df5_10.iloc[:, 1:]*100, cmap='Blues', annot=True, fmt='0.2f')
# 设置右侧柱子的单位
cbar = heatmap.collections[0].colorbar
cbar.set_label('x0.01', rotation=90)

plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('表5-10 一级指标部分问卷得分情况.xlsx.svg')
plt.show()
